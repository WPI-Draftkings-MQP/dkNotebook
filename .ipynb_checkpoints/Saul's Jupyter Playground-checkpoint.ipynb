# %% [markdown]
# # Saul's Jupyter Playground

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
sns.set(style="darkgrid")

# %% [markdown]
# ## Contest Data

# %%
df = pd.read_csv('data/Contests.csv')
df.head()
#df.tail()
# Out:
#    ContestId SportName VariantName  GameSet  \
# 0    7963004       NFL     Classic   (Main)
# 1    7963437       NFL     Classic   (Main)
# 2    8296224       NFL     Classic   (Main)
# 3    8296543       NFL     Classic   (Main)
# 4    8296544       NFL     Classic   (Main)
#
#                                  ContestName  ContestStartDatetimeEST  \
# 0      NFL $25K Quarter Arcade [Just $0.25!]  2015-09-13 13:00:00.000
# 1   NFL GIANT $2 Booster [Top 1,250 Win $20]  2015-09-13 13:00:00.000
# 2        Beginner NFL $5K Spy [Single Entry]  2015-09-13 13:00:00.000
# 3  NFL $50 Double Up [$5K Gtd] (Multi-Entry)  2015-09-13 13:00:00.000
# 4  NFL $50 Double Up [$5K Gtd] (Multi-Entry)  2015-09-13 13:00:00.000
#
#      ContestEndDatetimeEST ContestPayoutDatetimeEST  EntryFeeAmount  \
# 0  2015-09-14 22:20:00.000  2015-09-15 02:27:24.000            0.25
# 1  2015-09-14 22:20:00.000  2015-09-15 02:27:24.000            2.00
# 2  2015-09-14 22:20:00.000  2015-09-15 02:27:24.000          100.00
# 3  2015-09-14 22:20:00.000  2015-09-15 02:27:24.000           50.00
# 4  2015-09-14 22:20:00.000  2015-09-15 02:27:24.000           50.00
#
#    TotalPrizeAmount  MaxNumberPlayers  MaxEntriesPerUser   Entries  \
# 0           25000.0            117500                100  117500.0
# 1           25000.0             14375                100   14375.0
# 2            5000.0                55                  1      55.0
# 3            5000.0               111                 11     111.0
# 4            5000.0               111                 11     111.0
#
#    DistinctUsers     Contest_Group  NumGames  DraftablePlayersInSet  \
# 0          38925         Headliner        15                  910.0
# 1           9663           Booster        15                  910.0
# 2             55       SingleEntry        15                  910.0
# 3             79  FeaturedDoubleUp        15                  910.0
# 4             91  FeaturedDoubleUp        15                  910.0
#
#    PaidUsersInDraftGroup  TopPrize  MaxPayoutPosition
# 0                 668396    2000.0              23665
# 1                 668396      20.0               1250
# 2                 668396    1100.0                 11
# 3                 668396     100.0                 50
# 4                 668396     100.0                 50

# %%
df.dtypes
# Out:
# ContestId                     int64
# SportName                    object
# VariantName                  object
# GameSet                      object
# ContestName                  object
# ContestStartDatetimeEST      object
# ContestEndDatetimeEST        object
# ContestPayoutDatetimeEST     object
# EntryFeeAmount              float64
# TotalPrizeAmount            float64
# MaxNumberPlayers              int64
# MaxEntriesPerUser             int64
# Entries                     float64
# DistinctUsers                 int64
# Contest_Group                object
# NumGames                      int64
# DraftablePlayersInSet       float64
# PaidUsersInDraftGroup         int64
# TopPrize                    float64
# MaxPayoutPosition             int64
# dtype: object

# %% [markdown]
# ^^^ The fact that EntryFeeAmount thru MaxPayoutPosition are all float64/int64 is a pretty good indication that we aren't missing data there!

# %%
counts = df.groupby('SportName')['ContestId'].nunique().sort_values(ascending=False)
counts.plot(kind='bar', title="Number of Contests per Sport")

# %% [markdown]
# ## Time Series Data

# %%
timeDF = pd.read_csv('data/WPI/2017-09.csv', header=None)
timeDF.columns = ['ContestID', 'MinutesRemaining', 'Entries']
timeDF.tail()
# Out:
#          ContestID  MinutesRemaining  Entries
# 4073938   45735562                24        2
# 4073939   45735562                25        1
# 4073940   45735562                26        2
# 4073941   45735562                27        2
# 4073942   45735562                28        1

# %%
timeDF = timeDF.pivot(index='ContestID', columns='MinutesRemaining', values='Entries')
timeDF.head()
# Out:
# ContestID         43229169  43229170  43229171  43229271  43231454  43231455  \
# MinutesRemaining
# 0                      NaN      14.0      20.0       NaN       NaN       NaN
# 1                      NaN    1714.0    1277.0       NaN       2.0       NaN
# 2                      NaN    1599.0     865.0       NaN       1.0       NaN
# 3                      NaN    1449.0     801.0       NaN       NaN       NaN
# 4                      NaN    1366.0     641.0       NaN       NaN       NaN
#
# ContestID         43231456  43231457  43231458  43231460    ...     45729856  \
# MinutesRemaining                                            ...
# 0                      NaN       NaN       1.0       NaN    ...          NaN
# 1                      NaN       3.0      59.0       NaN    ...         35.0
# 2                      NaN       1.0      57.0       NaN    ...         28.0
# 3                      NaN       NaN      55.0       NaN    ...         25.0
# 4                      NaN       1.0      63.0       NaN    ...         27.0
#
# ContestID         45730341  45730376  45730386  45731413  45732440  45732552  \
# MinutesRemaining
# 0                      NaN       NaN       NaN       NaN       NaN       NaN
# 1                     21.0       NaN       NaN       NaN       NaN       NaN
# 2                     13.0       1.0       NaN       NaN       NaN       NaN
# 3                     11.0       1.0       NaN       NaN       NaN       NaN
# 4                     14.0       2.0       NaN       NaN       NaN       NaN
#
# ContestID         45733884  45734819  45735562
# MinutesRemaining
# 0                      NaN       NaN       NaN
# 1                      1.0       NaN       NaN
# 2                     11.0      20.0       NaN
# 3                      5.0      15.0       NaN
# 4                      6.0      18.0       NaN
#
# [5 rows x 19002 columns]

# %%
timeDF.plot()

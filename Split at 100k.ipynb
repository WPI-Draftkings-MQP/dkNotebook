# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
contests = pd.read_csv('data/WorkingData.csv').set_index('ContestId')[['TotalPrizeAmount']]

# %%
contests = pd.read_csv('data/WorkingData.csv').set_index('ContestId')

# %%
largBois = contests.loc[contests['Entries']> 4000]

# %%
largBois.head(12050).tail()
# Out:
#           SportName VariantName   GameSet  \
# ContestId
# 25217250        MLB     Classic    (Main)
# 25218479        MLB     Classic    (Main)
# 50767627        NBA     Classic   (Early)
# 52152366        NBA     Classic    (Main)
# 52152369        NBA     Classic    (Main)
#
#                                              ContestName  \
# ContestId
# 25217250    MLB $200K Sunday Fifty [$200,000 Guaranteed]
# 25218479          MLB $400K SUPER Slurve [$100K to 1st!]
# 50767627   NBA $4K Quarter Jukebox [Just $0.25!] (Early)
# 52152366                 NBA $35K And-One [20 Entry Max]
# 52152369           NBA $130K Sharpshooter [20 Entry Max]
#
#            ContestStartDatetimeEST    ContestEndDatetimeEST  \
# ContestId
# 25217250   2016-06-12 13:07:00.000  2016-06-12 15:35:00.000
# 25218479   2016-06-13 19:05:00.000  2016-06-13 22:15:00.000
# 50767627   2017-12-09 15:30:00.000  2017-12-09 18:00:00.000
# 52152366   2018-01-03 19:00:00.000  2018-01-03 22:30:00.000
# 52152369   2018-01-03 19:00:00.000  2018-01-03 22:30:00.000
#
#           ContestPayoutDatetimeEST  EntryFeeAmount  TotalPrizeAmount  \
# ContestId
# 25217250   2016-06-12 19:26:50.000           50.00          200000.0
# 25218479   2016-06-14 02:19:04.000            4.00          400000.0
# 50767627   2017-12-09 22:15:49.000            0.25            4000.0
# 52152366   2018-01-04 01:18:09.000            1.00           35000.0
# 52152369   2018-01-04 01:18:09.000            3.00          130000.0
#
#            MaxNumberPlayers  MaxEntriesPerUser   Entries  DistinctUsers  \
# ContestId
# 25217250               4494                200    4494.0           1846
# 25218479             115000                500  112722.0          31768
# 50767627              19024                 20   19024.0           7335
# 52152366              41617                 20   41617.0          15260
# 52152369              51525                 20   51525.0          22583
#
#           Contest_Group  NumGames  DraftablePlayersInSet  \
# ContestId
# 25217250      Headliner         9                  697.0
# 25218479      Headliner        10                  793.0
# 50767627      Headliner         2                   67.0
# 52152366      Headliner        12                  397.0
# 52152369      Headliner        12                  397.0
#
#            PaidUsersInDraftGroup  TopPrize  MaxPayoutPosition  is_vault
# ContestId
# 25217250                   30650   30000.0                990     False
# 25218479                   54712  100000.0              23320     False
# 50767627                   32080     250.0               3956     False
# 52152366                   79402    2000.0              10456     False
# 52152369                   79402    5000.0              14900     False

# %%
smallDF, bigDF = contests.loc[contests['TotalPrizeAmount'] < 100000], contests.loc[contests['TotalPrizeAmount'] >= 100000]

# %%
len(bigDF), len(smallDF)
# Out:
# (5401, 366810)

# %%
bigDF.to_csv('data/BigContests.csv')
smallDF.to_csv('data/SmallContests.csv')

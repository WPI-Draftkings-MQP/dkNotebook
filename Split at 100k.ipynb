# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
contests = pd.read_csv('data/WorkingData.csv').set_index('ContestId')[['TotalPrizeAmount']]

# %%
contests = pd.read_csv('data/WorkingData.csv').set_index('ContestId')

# %%
largBois = contests.loc[contests['Entries']> 4000]

# %%
largBois.head(4000).tail()
# Out:
#           SportName VariantName     GameSet  \
# ContestId
# 22028160        PGA     Classic      (Main)
# 22035300        NBA     Classic      (Main)
# 17477714        NBA     Classic      (Main)
# 17477722        NBA     Classic      (Main)
# 17479943        NFL     Classic   (Mon-Thu)
#
#                                                  ContestName  \
# ContestId
# 22028160        PGA $2 Double Up [$10,000 Gtd] (Multi-Entry)
# 22035300         NBA GIANT $1 Double Up [$20,000 Guaranteed]
# 17477714               NBA $40K And-One [$40,000 Guaranteed]
# 17477722         NBA GIANT $5 Double Up [$75,000 Guaranteed]
# 17479943   NFL $12K Play-Action [$12,000 Guaranteed] (Mon...
#
#            ContestStartDatetimeEST    ContestEndDatetimeEST  \
# ContestId
# 22028160   2016-03-17 07:35:00.000  2016-03-20 07:35:00.000
# 22035300   2016-03-15 19:00:00.000  2016-03-15 22:30:00.000
# 17477714   2015-12-15 19:30:00.000  2015-12-15 22:30:00.000
# 17477722   2015-12-15 19:30:00.000  2015-12-15 22:30:00.000
# 17479943   2015-12-14 20:30:00.000  2015-12-17 20:25:00.000
#
#           ContestPayoutDatetimeEST  EntryFeeAmount  TotalPrizeAmount  \
# ContestId
# 22028160   2016-03-20 19:01:04.000             2.0           10000.0
# 22035300   2016-03-16 01:25:33.000             1.0           20000.0
# 17477714   2015-12-16 02:04:27.000             1.0           40000.0
# 17477722   2015-12-16 02:04:27.000             5.0           75000.0
# 17479943   2015-12-18 01:20:47.000             3.0           12000.0
#
#            MaxNumberPlayers  MaxEntriesPerUser  Entries  DistinctUsers  \
# ContestId
# 22028160               5681                 50   5681.0           1446
# 22035300              22727                200  22727.0           1954
# 17477714              47058                200  47058.0          23654
# 17477722              17045                100  17045.0           5067
# 17479943               4600                100   4600.0           3584
#
#               Contest_Group  NumGames  DraftablePlayersInSet  \
# ContestId
# 22028160   FeaturedDoubleUp         1                  120.0
# 22035300   FeaturedDoubleUp         6                  177.0
# 17477714          Headliner         4                  119.0
# 17477722   FeaturedDoubleUp         4                  119.0
# 17479943          Headliner         2                   66.0
#
#            PaidUsersInDraftGroup  TopPrize  MaxPayoutPosition  is_vault
# ContestId
# 22028160                   64670       4.0               2500     False
# 22035300                   70164       2.0              10000     False
# 17477714                  112705    3000.0               9310     False
# 17477722                  112705      10.0               7500     False
# 17479943                  134840    1000.0                935     False

# %%
smallDF, bigDF = contests.loc[contests['TotalPrizeAmount'] < 100000], contests.loc[contests['TotalPrizeAmount'] >= 100000]

# %%
len(bigDF), len(smallDF)
# Out:
# (5401, 366810)

# %%
bigDF.to_csv('data/BigContests.csv')
smallDF.to_csv('data/SmallContests.csv')
